// %% [markdown]
// # Atividade 03

// %% [markdown]
// ## Crie uma classe em java capaz de imprimir o seu nome no console.

// %%
//public class Bah {

  //  public static void main(String[] args) {
       // imp();
  //  }

   // public static void imp() {
        String nick = "dal"; 
        System.out.println("meu nome é: " + nick);
   // }
//}
// Out:
// meu nome é: dal
// null

// %% [markdown]
// ## Crie uma classe que efetue a leitura de um valor qualquer e exiba o seu respectivo valor na tabela ASCII.

// %%
import java.util.Scanner;

//public class bah {

   // public static void main(String[] args) {
        Scanner scanner = new Scanner(System.in);

        System.out.print("Digite");
        int valor = scanner.nextInt();


        char crt = (char) valor;
        System.out.println("O valor " + valor + " na tabela ASCII é: " + crt);
//}
// Out:
// Digite
//  1
// O valor 1 na tabela ASCII é:
// null
